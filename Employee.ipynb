# %% [markdown]
# <a href="https://colab.research.google.com/github/RamyahariniLogaiyan/Test-Proj-Repository/blob/main/Employee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
url='https://drive.google.com/file/d/13u5mQY3yU0fZZiHy3JJwwCI9m0wHLhoz/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    ID  Age Gender  Salary   Department    JoinDate  PerformanceScore
# 0   1   56   Male   79000  Engineering  2015-01-31                 3
# 1   2   69   Male  127500  Engineering  2015-02-28                 9
# 2   3   46   Male   88000           HR  2015-03-31                 5
# 3   4   32   Male  102000           HR  2015-04-30                 8
# 4   5   60   Male   67000  Engineering  2015-05-31                 1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(df["Salary"])
plt.show()
